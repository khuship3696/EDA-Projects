# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Indian Premier League

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
deli = pd.read_csv("C:\\Users\\kiran\\Downloads\\deliveries - deliveries.csv")

# %%
match = pd.read_csv("C:\\Users\\kiran\\Downloads\\matches - matches.csv")

# %%
deli.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
match.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
deli.shape
# Out:
# (179078, 21)

# %%
match.shape
# Out:
# (756, 18)

# %%
deli.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
match.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
deli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
deli.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
match.isnull().sum().sum()
# Out:
# 656

# %% [markdown]
# Total number of innings of the matches played?

# %%
deli['inning'].value_counts().sum()
# Out:
# 179078

# %% [markdown]
# How many IPL seasons are we using to analyse ?

# %%
match['season'].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018,
#        2019], dtype=int64)

# %% [markdown]
# Total number of matches played according to the dataset

# %%
match['season'].count()
# Out:
# 756

# %% [markdown]
# Which IPL team won by maximum runs?

# %%
match.loc[match['win_by_runs'].max()]['winner']
# Out:
# 'Deccan Chargers'

# %% [markdown]
# Which IPL team won by minimum runs ?

# %%
match.loc[match['win_by_runs'].min()]['winner']
# Out:
# 'Sunrisers Hyderabad'

# %% [markdown]
# Which IPL team won by consuming maximum wickets?

# %%
match.loc[match['win_by_wickets'].max()]['winner']
# Out:
# 'Kolkata Knight Riders'

# %% [markdown]
# Which IPL team won by consuming minimum wickets?

# %%
match.loc[match['win_by_wickets'].min()]['winner']
# Out:
# 'Sunrisers Hyderabad'

# %% [markdown]
# # Visualization Questions:

# %% [markdown]
# Que. Which season consisted of the highest number of matches ever played?

# %%
sns.countplot(x='season', data= match)
plt.title('Matches played in each season', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Matches played in each season')

# %% [markdown]
# 2013 it is, with highest number oof matches

# %% [markdown]
# Que. Which is the most successful IPL team with all the data in hand?

# %%
success = match.winner.value_counts()

# %%
success
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
sns.barplot(x=success,y=success.index)
plt.title('Most successful IPL team', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Most successful IPL team')

# %% [markdown]
# Mumbai Indians is the most succesful IPL team according to given data.

# %% [markdown]
# Que. Top players of winning matches?

# %%
tp = match.player_of_match.value_counts().head(10)

# %%
tp
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# Name: player_of_match, dtype: int64

# %%
sns.barplot(x=tp,y=tp.index)
plt.title('Top players of winning matches',fontsize=14)
# Out:
# Text(0.5, 1.0, 'Top players of winning matches')

# %% [markdown]
# Above are top players of einning matches

# %% [markdown]
# Que. Matches according to venue

# %%
matches = match.venue.value_counts().head(10)

# %%
matches
# Out:
# Eden Gardens                                  77
# M Chinnaswamy Stadium                         73
# Wankhede Stadium                              73
# Feroz Shah Kotla                              67
# Rajiv Gandhi International Stadium, Uppal     56
# MA Chidambaram Stadium, Chepauk               49
# Sawai Mansingh Stadium                        47
# Punjab Cricket Association Stadium, Mohali    35
# Maharashtra Cricket Association Stadium       21
# Subrata Roy Sahara Stadium                    17
# Name: venue, dtype: int64

# %%
sns.barplot(x=matches,y=matches.index)
plt.title('Matches according to venue',fontsize=14)
# Out:
# Text(0.5, 1.0, 'Matches according to venue')

# %% [markdown]
# Que. Number of matches played by each team?

# %%
a = match.team1.value_counts()
b = match.team2.value_counts()
mplayed = a+b

# %%
mplayed
# Out:
# Chennai Super Kings            164
# Deccan Chargers                 75
# Delhi Capitals                  16
# Delhi Daredevils               161
# Gujarat Lions                   30
# Kings XI Punjab                176
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          178
# Mumbai Indians                 187
# Pune Warriors                   46
# Rajasthan Royals               147
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    180
# Sunrisers Hyderabad            108
# dtype: int64

# %%
sns.barplot(x=mplayed,y=mplayed.index)
plt.title('Number of matches played by each team',fontsize=14)
# Out:
# Text(0.5, 1.0, 'Number of matches played by each team')

# %% [markdown]
# Que. The winners in each season

# %%
win = match.groupby(['season','winner'])['id'].count().reset_index()

# %%
win
# Out:
#     season                       winner  id
# 0     2008          Chennai Super Kings   9
# 1     2008              Deccan Chargers   2
# 2     2008             Delhi Daredevils   7
# 3     2008              Kings XI Punjab  10
# 4     2008        Kolkata Knight Riders   6
# ..     ...                          ...  ..
# 95    2019        Kolkata Knight Riders   6
# 96    2019               Mumbai Indians  11
# 97    2019             Rajasthan Royals   5
# 98    2019  Royal Challengers Bangalore   5
# 99    2019          Sunrisers Hyderabad   6
#
# [100 rows x 3 columns]

# %%
win.pivot_table(values='winner',index='season',columns='winner').fillna(0)
# Out:
# winner  Chennai Super Kings  Deccan Chargers  Delhi Capitals  \
# season
# 2008                    9.0              2.0             0.0
# 2009                    8.0              9.0             0.0
# 2010                    9.0              8.0             0.0
# 2011                   11.0              6.0             0.0
# 2012                   10.0              4.0             0.0
# 2013                   12.0              0.0             0.0
# 2014                   10.0              0.0             0.0
# 2015                   10.0              0.0             0.0
# 2016                    0.0              0.0             0.0
# 2017                    0.0              0.0             0.0
# 2018                   11.0              0.0             0.0
# 2019                   10.0              0.0            10.0
#
# winner  Delhi Daredevils  Gujarat Lions  Kings XI Punjab  \
# season
# 2008                 7.0            0.0             10.0
# ...

# %%
a = win.pivot_table(values='winner',index='season',columns='winner').fillna(0)
sns.heatmap(a)
# Out:
# <Axes: xlabel='winner', ylabel='season'>

# %% [markdown]
# Que. IPL finals venues and winners along with the number of wins

# %%
final_match = match.loc[match.groupby('season')['id'].idxmax()]
venue_win = final_match.groupby(['city','winner']).size().reset_index(name='num_wins')
plt.figure(figsize= (12,6))
for team in venue_win['winner'].unique():
    team_data = venue_win[venue_win['winner'] == team]
    plt.bar(team_data['city'], team_data['num_wins'], label=team)
    
plt.xlabel('Venue')
plt.ylabel('Number of Wins')
plt.title('IPL final venues and winners along with the number of wins')
plt.legend()

# %% [markdown]
# Que. The number of seasons won by each team

# %%
swon = match.groupby('winner')['season'].nunique()
print('Number of seasons won by each team:\n',swon)
plt.figure(figsize= (12,6))
swon.plot(kind='bar')

plt.xlabel('Season')
plt.ylabel('Number of seasons won')
plt.title('Number of season won by each team')
plt.legend()
# Out:
# Number of seasons won by each team:
#  winner
# Chennai Super Kings            10
# Deccan Chargers                 5
# Delhi Capitals                  1
# Delhi Daredevils               11
# Gujarat Lions                   2
# Kings XI Punjab                12
# Kochi Tuskers Kerala            1
# Kolkata Knight Riders          12
# Mumbai Indians                 12
# Pune Warriors                   3
# Rajasthan Royals               10
# Rising Pune Supergiant          1
# Rising Pune Supergiants         1
# Royal Challengers Bangalore    12
# Sunrisers Hyderabad             7
# Name: season, dtype: int64

# %% [markdown]
# Que. The toss winner, toss decision, winner in final matches

# %%
toss_win = match.groupby(['toss_winner','toss_decision','winner']).size().reset_index(name='count')
a = toss_win.pivot_table(index='toss_winner',columns=['toss_decision'],values='count').fillna(0)

plt.figure(figsize= (12,6))
a.plot(kind='bar')
plt.xlabel('Toss Winner')
plt.ylabel('Count')
plt.title('Toss winner,Decision, and Matches Won')
plt.show()

# %% [markdown]
# Que. The man of the match for each winning team

# %%
mom = match.groupby('winner')['player_of_match'].first().reset_index()
plt.figure(figsize= (12,6))
plt.barh(mom['winner'],mom['player_of_match'],color='green')

plt.xlabel('Player')
plt.ylabel('Team')
plt.title('Man of the match for each winning team')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# Que. Decision in every toss either fielding or batting

# %%
tossw = match.toss_decision.value_counts()
tossw
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %%
plt.figure(figsize= (!2,6))
sns.countplot(x= 'season',hue='toss_decision',data=match)
plt.show()
# Out:
#   Cell In[20], line 1
#     plt.figure(figsize= (!2,6))
#                          ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='season',hue='toss_decision',data=match)
plt.show()

# %% [markdown]
# Que. What is the probability of winning a match if the toss was won

# %%
twon = match[match['toss_winner'] == match['winner']]
total_match = match.shape[0]
toss_win_match = twon.shape[0]
prob_of_winning = toss_win_match/total_match

plt.figure(figsize= (12,6))
sns.barplot(x=['Probability of winning toss and match','Probability of losing toss and winning match'],
           y=[prob_of_winning, 1- prob_of_winning])

plt.title('Probability of winning a match based on toss result')
plt.ylabel=('Probability')
plt.show()

# %% [markdown]
# Que. The total runs by fours hit and the total number of fours hit by each team

# %%
fours = deli[deli['batsman_runs']==4]
a = fours.groupby('batting_team')['batsman_runs'].agg([('Total runs by fours','count')]).reset_index()
a
# Out:
#                    batting_team  Total runs by fours
# 0           Chennai Super Kings                 2193
# 1               Deccan Chargers                  957
# 2                Delhi Capitals                  242
# 3              Delhi Daredevils                 2158
# 4                 Gujarat Lions                  460
# 5               Kings XI Punjab                 2458
# 6          Kochi Tuskers Kerala                  170
# 7         Kolkata Knight Riders                 2434
# 8                Mumbai Indians                 2588
# 9                 Pune Warriors                  525
# 10             Rajasthan Royals                 2035
# 11       Rising Pune Supergiant                  197
# 12      Rising Pune Supergiants                  171
# 13  Royal Challengers Bangalore                 2360
# 14          Sunrisers Hyderabad                 1444

# %%
a.plot(kind='bar',color='purple')
# Out:
# <Axes: >

# %% [markdown]
# Que. The fours hit by players

# %%
four = deli[deli['batsman_runs']==4]
a = four.groupby('batsman')['batsman_runs'].agg([('four','count')]).reset_index()
a
# Out:
#                 four
# batsman
# A Ashish Reddy    16
# A Chopra           7
# A Choudhary        1
# A Flintoff         5
# A Hales           13
# ...              ...
# YK Pathan        264
# YV Takawale       26
# Yashpal Singh      5
# Yuvraj Singh     218
# Z Khan            11
#
# [410 rows x 1 columns]

# %%
m =a.iloc[:10].plot(x='batsman',y='four',kind='bar')

# %% [markdown]
# Que. The number of fours hit in each season

# %%
fours_data = deli[deli['total_runs']==4]
fours_season = match.groupby('season').size()
plt.figure(figsize= (12,6))

fours_season.plot(kind='bar',color='yellow')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Que. The total runs by the sixes hit and the number of sixes hit by each team

# %%
a = deli.groupby('batting_team')['batsman_runs'].agg([('total runs by six','count')]).reset_index()
a
# Out:
#                    batting_team  total runs by six
# 0           Chennai Super Kings              19762
# 1               Deccan Chargers               9034
# 2                Delhi Capitals               1909
# 3              Delhi Daredevils              18786
# 4                 Gujarat Lions               3566
# 5               Kings XI Punjab              20931
# 6          Kochi Tuskers Kerala               1582
# 7         Kolkata Knight Riders              20858
# 8                Mumbai Indians              22619
# 9                 Pune Warriors               5443
# 10             Rajasthan Royals              17292
# 11       Rising Pune Supergiant               1900
# 12      Rising Pune Supergiants               1580
# 13  Royal Challengers Bangalore              20908
# 14          Sunrisers Hyderabad              12908

# %%
a.plot(kind='bar',colormap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Que. The number of sixes hit in each season

# %%
six = deli[deli['total_runs']==6]
six_season = match.groupby('season').size()
plt.figure(figsize= (12,6))

# %%
six_season.plot(kind='bar',color='green')
plt.show()

# %% [markdown]
# Que. The top 10 leading run scorers in IPL

# %%
top_score = deli.groupby('batsman')['batsman_runs'].sum()
top_score = top_score.sort_values(ascending=False).head(10)
plt.figure(figsize= (12,6))

# %%
top_score.plot(kind='bar',color='pink')
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this comprehensive data analysis project centered around the Indian Premier League (IPL), I harnessed the power of Python libraries such as pandas, numpy, and matplotlib to delve into a wealth of data spanning IPL matches from 2008 to 2017. My analysis encompassed both player-level information, including batting and bowling statistics, and match-level details such as venues, winners, and scores. With the overarching aim of shedding light on various dimensions of IPL games, I meticulously applied data cleaning techniques to ensure the integrity and relevance of the dataset. Throughout this analysis, I diligently tackled several pivotal questions that have piqued the curiosity of IPL enthusiasts and data professionals alike.
